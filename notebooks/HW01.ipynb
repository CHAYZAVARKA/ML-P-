# %%
import sys
print(sys.executable)
# Out:
# C:\Users\ukohn\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
import numpy
import pandas
import matplotlib
import seaborn
import sklearn

print("Все библиотеки работают!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy
#       2 import pandas
#       3 import matplotlib
#
# ModuleNotFoundError: No module named 'numpy'
