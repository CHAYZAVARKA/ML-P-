# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sns.set(style="whitegrid")

# %%
# %matplotlib inline

# %%
from sklearn.preprocessing import LabelEncoder

# %%
import sys
# !{sys.executable} -m pip install category_encoders
from category_encoders import HashingEncoder

# %%
train_df = pd.read_csv('E:/ДушитьУдава/ML-P-/notebooks/hw2forDATASET/titanic/train.csv')
test_df = pd.read_csv('E:/ДушитьУдава/ML-P-/notebooks/hw2forDATASET/titanic/test.csv')
gender_submission_df = pd.read_csv('E:/ДушитьУдава/ML-P-/notebooks/hw2forDATASET/titanic/gender_submission.csv')

# %%
# Посмотреть первые и последние строки
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
train_df.shape
# Out:
# (891, 12)

# %%
# Общая информация о колонках, типах и пропусках
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
# Статистика по числовым колонкам
train_df.describe()
train_df.describe(include="string")
# Out:
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
# Пропуски
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Дубликаты
train_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Две пропущенные в embarked и очень много в cabin
train_df[['Sex', 'Embarked', 'Cabin']].isnull().sum()
# Out:
# Sex           0
# Embarked      2
# Cabin       687
# dtype: int64

# %%
mode_embarked = train_df['Embarked'].mode()[0]#мода
train_df['Embarked'].fillna(mode_embarked, inplace=True)#заполняем
# Out:
# C:\Users\ukohn\AppData\Local\Temp\ipykernel_20004\1101099280.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   train_df['Embarked'].fillna(mode_embarked, inplace=True)#заполняем
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# ...

# %%
train_df['Embarked'].isnull().sum()
# Out:
# np.int64(2)

# %%
# Age медиана, чтобы не была чувствительна к выбросам при сильном разбросе данных (возраста)
train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
# Embarked мода, тк не может быть промежуточного. Только определенные категории
train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)
# Cabin удаляем, потому что если модель начнет предсказывать имея малое количество данных, то скорее всего она ошибётся
train_df.dropna(columns=['Cabin'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Age медиана, чтобы не была чувствительна к выбросам при сильном разбросе данных (возраста)
# ----> 2 train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
#       3 # Embarked мода, тк не может быть промежуточного. Только определенные категории
#       4 train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)
#
# NameError: name 'train_df' is not defined
